# %% [markdown]
# *Step 0 : Import And Read The Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

from scipy import stats

import re
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('RealEstateAU_1000_Samples.csv')
df= pd.DataFrame(data)
df.head(5)
# Out:
#    index      TID          breadcrumb  \
# 0      0  1350988  Buy>NT>DARWIN CITY
# 1      1  1350989  Buy>NT>DARWIN CITY
# 2      2  1350990  Buy>NT>DARWIN CITY
# 3      3  1350991  Buy>NT>DARWIN CITY
# 4      4  1350992  Buy>NT>DARWIN CITY
#
#                                        category_name property_type  \
# 0  Real Estate & Property for sale in DARWIN CITY...         House
# 1  Real Estate & Property for sale in DARWIN CITY...     Apartment
# 2  Real Estate & Property for sale in DARWIN CITY...          Unit
# 3  Real Estate & Property for sale in DARWIN CITY...         House
# 4  Real Estate & Property for sale in DARWIN CITY...          Unit
#
#   building_size land_size preferred_size           open_date  \
# 0           NaN       NaN            NaN   Added 2 hours ago
# 1         171m²       NaN          171m²   Added 7 hours ago
# 2           NaN       NaN            NaN  Added 22 hours ago
# 3           NaN       NaN            NaN     Added yesterday
# 4         201m²       NaN          201m²     Added yesterday
#
#                                     listing_agency  ... state  zip_code  \
# 0                      Professionals - DARWIN CITY  ...    NT       800
# 1  Nick Mousellis Real Estate - Eview Group Member  ...    NT       800
# 2                Habitat Real Estate - THE GARDENS  ...    NT       800
# 3                           Ray White - NIGHTCLIFF  ...    NT       800
# 4              Carol Need Real Estate - Fannie Bay  ...    NT       800
#
#           phone latitude longitude product_depth bedroom_count bathroom_count  \
# 0  08 8941 8289      NaN       NaN      premiere           2.0            1.0
# 1    0411724000      NaN       NaN      premiere           3.0            2.0
# 2  08 8981 0080      NaN       NaN      premiere           2.0            1.0
# 3  08 8982 2403      NaN       NaN      premiere           1.0            1.0
# 4    0418885966      NaN       NaN      premiere           3.0            2.0
#
#    parking_count              RunDate
# 0            1.0  2022-05-27 15:54:05
# 1            2.0  2022-05-27 15:54:05
# 2            1.0  2022-05-27 15:54:05
# 3            0.0  2022-05-27 15:54:05
# 4            2.0  2022-05-27 15:54:05
#
# [5 rows x 27 columns]

# %% [markdown]
# *Step 1: Data Understanding
# .shape , .head() , .tail() , .columns

# %%
df.shape
# Out:
# (1000, 27)

# %%
df.columns
# Out:
# Index(['index', 'TID', 'breadcrumb', 'category_name', 'property_type',
#        'building_size', 'land_size', 'preferred_size', 'open_date',
#        'listing_agency', 'price', 'location_number', 'location_type',
#        'location_name', 'address', 'address_1', 'city', 'state', 'zip_code',
#        'phone', 'latitude', 'longitude', 'product_depth', 'bedroom_count',
#        'bathroom_count', 'parking_count', 'RunDate'],
#       dtype='object')

# %% [markdown]
# *Step 2: Data Preparation
# - Drop irrelevant columns
# - Identify and Drop rows with missing values
# - Change the DataType for price column

# %%
#Dropping irrelevant columns
df=df[[#'index', 'TID', 'breadcrumb','category_name', 
    'property_type',
       #'building_size', 'land_size', 'preferred_size', 'open_date',
       'listing_agency', 'price', 'location_number', #'location_type',
       'location_name', 
        #'address', 'address_1', 
        'city', 'state', 'zip_code',
        #'phone', 
       'latitude', 'longitude', 'product_depth', 'bedroom_count',
       'bathroom_count', 'parking_count', 'RunDate']]
df.head()
# Out:
#   property_type                                   listing_agency  \
# 0         House                      Professionals - DARWIN CITY
# 1     Apartment  Nick Mousellis Real Estate - Eview Group Member
# 2          Unit                Habitat Real Estate - THE GARDENS
# 3         House                           Ray White - NIGHTCLIFF
# 4          Unit              Carol Need Real Estate - Fannie Bay
#
#                   price  location_number         location_name         city  \
# 0              $435,000        139468611              $435,000  Darwin City
# 1  Offers Over $320,000        139463755  Offers Over $320,000  Darwin City
# 2              $310,000        139462495              $310,000  Darwin City
# 3              $259,000        139451679              $259,000  Darwin City
# 4              $439,000        139433803              $439,000  Darwin City
#
#   state  zip_code  latitude  longitude product_depth  bedroom_count  \
# 0    NT       800       NaN        NaN      premiere            2.0
# 1    NT       800       NaN        NaN      premiere            3.0
# 2    NT       800       NaN        NaN      premiere            2.0
# 3    NT       800       NaN        NaN      premiere            1.0
# 4    NT       800       NaN        NaN      premiere            3.0
#
#    bathroom_count  parking_count              RunDate
# 0             1.0            1.0  2022-05-27 15:54:05
# 1             2.0            2.0  2022-05-27 15:54:05
# 2             1.0            1.0  2022-05-27 15:54:05
# 3             1.0            0.0  2022-05-27 15:54:05
# 4             2.0            2.0  2022-05-27 15:54:05

# %%
#Checking Missing Values
df.isna().sum()
# Out:
# property_type         0
# listing_agency        0
# price                 0
# location_number       0
# location_name         0
# city                  0
# state                 0
# zip_code              0
# latitude           1000
# longitude          1000
# product_depth         0
# bedroom_count        33
# bathroom_count       33
# parking_count        33
# RunDate               0
# dtype: int64

# %% [markdown]
# - step   : Check the number of missing values(NaaN)in each columns using .isna().sum()
# - result : We indentified that latitude and longitude columns have the maximum mising values.
# - action : Drop latitude and longitude columns

# %%
#Dropping latitude and longitude columns
df_1= df.drop(['latitude','longitude'], axis=1)
df_1.isna().sum()
# Out:
# property_type       0
# listing_agency      0
# price               0
# location_number     0
# location_name       0
# city                0
# state               0
# zip_code            0
# product_depth       0
# bedroom_count      33
# bathroom_count     33
# parking_count      33
# RunDate             0
# dtype: int64

# %%
#Finding pairs of columns with more than 90% similarity
duplicate_columns =[]
threshold = 0.9* len(df_1)

for col_1 in df_1.columns:
    for col_2 in df_1.columns:
        if col_1 != col_2 and (col_2 ,col_1 ) not in duplicate_columns:
            similarity_count = (df_1[col_1] == df_1[col_2]).sum()
            if similarity_count > threshold:
                duplicate_columns.append((col_1 ,col_2 ))

duplicate_columns
# Out:
# [('price', 'location_name')]

# %% [markdown]
# - Step   : Identify columns with more than 90% similarity, which can be a sign of data duplication. That will help in detecting redundancy and making subsewuent analyses more efficient and interpretable.
# - Result : price & location_name columns have more than 90% of similarity. This finding is surpricing as price and location name are not typlically expected to be similar.
# - Action : Dropping location_name column to eliminate redundancy in dataset.

# %%
#Droppoing location_name column
df_2 = df_1.drop(columns=['location_name'])
df_2.columns
# Out:
# Index(['property_type', 'listing_agency', 'price', 'location_number', 'city',
#        'state', 'zip_code', 'product_depth', 'bedroom_count', 'bathroom_count',
#        'parking_count', 'RunDate'],
#       dtype='object')

# %%
#Check if all the values in each column are the same

columns_with_same_values = []

for col in df_2.columns:
    first_value = df_2[col].loc[0]
    
    if df_2[col].eq(first_value).all():
        columns_with_same_values.append(col)

columns_with_same_values
# Out:
# ['state', 'RunDate']

# %% [markdown]
# - Step   : Check if all values in each columns are the same.
# - Result : state & RunDate columns have the same values in each rows. Constant columns don't contribute to statistical analysis or models, as they don't provide any variation in observation.
# - Action : Drop state & RunDate columns

# %%
#Drop state & RunDate columns
df_3 = df_2.drop(columns=['state', 'RunDate'])
df_3.columns
# Out:
# Index(['property_type', 'listing_agency', 'price', 'location_number', 'city',
#        'zip_code', 'product_depth', 'bedroom_count', 'bathroom_count',
#        'parking_count'],
#       dtype='object')

# %%
df_3.isna().sum()
# Out:
# property_type       0
# listing_agency      0
# price               0
# location_number     0
# city                0
# zip_code            0
# product_depth       0
# bedroom_count      33
# bathroom_count     33
# parking_count      33
# dtype: int64

# %%
df_3.shape
# Out:
# (1000, 10)

# %% [markdown]
# - Step : Check for any further Missing values :
# - Result :bedroom_count, bathroom_count and parking_count have 33 missing values
# - Action : Drop missing values

# %%
df_4 = df_3.dropna()
df_4.isna().sum()
# Out:
# property_type      0
# listing_agency     0
# price              0
# location_number    0
# city               0
# zip_code           0
# product_depth      0
# bedroom_count      0
# bathroom_count     0
# parking_count      0
# dtype: int64

# %%
df_4
# Out:
#     property_type                                   listing_agency  \
# 0           House                      Professionals - DARWIN CITY
# 1       Apartment  Nick Mousellis Real Estate - Eview Group Member
# 2            Unit                Habitat Real Estate - THE GARDENS
# 3           House                           Ray White - NIGHTCLIFF
# 4            Unit              Carol Need Real Estate - Fannie Bay
# ..            ...                                              ...
# 995         House                         United Realty NT - Parap
# 996         House           Kassiou Constructions - HOWARD SPRINGS
# 997         House           Kassiou Constructions - HOWARD SPRINGS
# 998         House           Kassiou Constructions - HOWARD SPRINGS
# 999          Unit                            Home Zone NT - DARWIN
#
#                     price  location_number         city  zip_code  \
# 0                $435,000        139468611  Darwin City       800
# 1    Offers Over $320,000        139463755  Darwin City       800
# 2                $310,000        139462495  Darwin City       800
# 3                $259,000        139451679  Darwin City       800
# 4                $439,000        139433803  Darwin City       800
# ..                    ...              ...          ...       ...
# 995           2 Residence        138346247     Virginia       834
# 996              $601,000        138333062   Humpty Doo       836
# 997              $655,000        138333058   Humpty Doo       836
# 998              $675,000        138333050    Lee Point       810
# 999              $399,000        138330946  Stuart Park       820
#
#     product_depth  bedroom_count  bathroom_count  parking_count
# 0        premiere            2.0             1.0            1.0
# 1        premiere            3.0             2.0            2.0
# 2        premiere            2.0             1.0            1.0
# 3        premiere            1.0             1.0            0.0
# 4        premiere            3.0             2.0            2.0
# ..            ...            ...             ...            ...
# 995       feature            4.0             3.0            6.0
# 996      standard            4.0             2.0            2.0
# 997      standard            4.0             2.0            2.0
# 998      standard            4.0             2.0            3.0
# 999       feature            2.0             2.0            2.0
#
# [967 rows x 10 columns]

# %%
#Extract Price from the text (ex :Offers Over $320,000 )
def extract_price(price_text):
    
    #Using regex to find a pattern that matches the price and ignores any following text
    price_match = re.search(r'\$[\d, ]*(?:\.\d{2})?' , str(price_text))
    
    if price_match:
        
        #remove spaces from the captured price and return
        return price_match.group(0).replace('','').replace('','')
    else:
        return None

#Applying the function to the price column in dataset
df_4['price'] = df_4['price'].apply(extract_price)

df_4.head()
# Out:
#   property_type                                   listing_agency     price  \
# 0         House                      Professionals - DARWIN CITY  $435,000
# 1     Apartment  Nick Mousellis Real Estate - Eview Group Member  $320,000
# 2          Unit                Habitat Real Estate - THE GARDENS  $310,000
# 3         House                           Ray White - NIGHTCLIFF  $259,000
# 4          Unit              Carol Need Real Estate - Fannie Bay  $439,000
#
#    location_number         city  zip_code product_depth  bedroom_count  \
# 0        139468611  Darwin City       800      premiere            2.0
# 1        139463755  Darwin City       800      premiere            3.0
# 2        139462495  Darwin City       800      premiere            2.0
# 3        139451679  Darwin City       800      premiere            1.0
# 4        139433803  Darwin City       800      premiere            3.0
#
#    bathroom_count  parking_count
# 0             1.0            1.0
# 1             2.0            2.0
# 2             1.0            1.0
# 3             1.0            0.0
# 4             2.0            2.0

# %% [markdown]
# - Step : Remove aditional text from the price value ( ex.Offers Over $320,000) . Design a function to Return the price value in $100,000 format
# - Result : The function uses a redular expression(regex) to extract the numeric price value, including the $ symbol.
# - Action : Transformed the price values into a consistent formate that can be used for numerical analysis.

# %%
df_4.isna().sum()
# Out:
# property_type        0
# listing_agency       0
# price              223
# location_number      0
# city                 0
# zip_code             0
# product_depth        0
# bedroom_count        0
# bathroom_count       0
# parking_count        0
# dtype: int64

# %%
df_5 = df_4.dropna()
df_5.isna().sum()
# Out:
# property_type      0
# listing_agency     0
# price              0
# location_number    0
# city               0
# zip_code           0
# product_depth      0
# bedroom_count      0
# bathroom_count     0
# parking_count      0
# dtype: int64

# %%
df_5.head(2)
# Out:
#   property_type                                   listing_agency     price  \
# 0         House                      Professionals - DARWIN CITY  $435,000
# 1     Apartment  Nick Mousellis Real Estate - Eview Group Member  $320,000
#
#    location_number         city  zip_code product_depth  bedroom_count  \
# 0        139468611  Darwin City       800      premiere            2.0
# 1        139463755  Darwin City       800      premiere            3.0
#
#    bathroom_count  parking_count
# 0             1.0            1.0
# 1             2.0            2.0

# %%
#Remove currency symbol and 
# convert price column into a integer datatype
df_5_copy = df_5.copy()

df_5_copy['price'] = df_5_copy['price'].replace('[\$, .]', '' , regex=True).astype(int)
df_6 = df_5_copy
df_6 = df_6.reset_index(drop=True)
df_6
# Out:
#     property_type                                   listing_agency   price  \
# 0           House                      Professionals - DARWIN CITY  435000
# 1       Apartment  Nick Mousellis Real Estate - Eview Group Member  320000
# 2            Unit                Habitat Real Estate - THE GARDENS  310000
# 3           House                           Ray White - NIGHTCLIFF  259000
# 4            Unit              Carol Need Real Estate - Fannie Bay  439000
# ..            ...                                              ...     ...
# 739         House                Real Estate Central - DARWIN CITY  495000
# 740         House           Kassiou Constructions - HOWARD SPRINGS  601000
# 741         House           Kassiou Constructions - HOWARD SPRINGS  655000
# 742         House           Kassiou Constructions - HOWARD SPRINGS  675000
# 743          Unit                            Home Zone NT - DARWIN  399000
#
#      location_number         city  zip_code product_depth  bedroom_count  \
# 0          139468611  Darwin City       800      premiere            2.0
# 1          139463755  Darwin City       800      premiere            3.0
# 2          139462495  Darwin City       800      premiere            2.0
# 3          139451679  Darwin City       800      premiere            1.0
# 4          139433803  Darwin City       800      premiere            3.0
# ..               ...          ...       ...           ...            ...
# 739        138350855    Woodroffe       830       feature            4.0
# 740        138333062   Humpty Doo       836      standard            4.0
# 741        138333058   Humpty Doo       836      standard            4.0
# 742        138333050    Lee Point       810      standard            4.0
# 743        138330946  Stuart Park       820       feature            2.0
#
#      bathroom_count  parking_count
# 0               1.0            1.0
# 1               2.0            2.0
# 2               1.0            1.0
# 3               1.0            0.0
# 4               2.0            2.0
# ..              ...            ...
# 739             2.0            2.0
# 740             2.0            2.0
# 741             2.0            2.0
# 742             2.0            3.0
# 743             2.0            2.0
#
# [744 rows x 10 columns]

# %%
df_6.dtypes
# Out:
# property_type       object
# listing_agency      object
# price                int32
# location_number      int64
# city                object
# zip_code             int64
# product_depth       object
# bedroom_count      float64
# bathroom_count     float64
# parking_count      float64
# dtype: object

# %%
#Cehck if the DataSet contains any Negative values # Select only numeric columns from above
negative_count = df_6[['price','location_number','zip_code','bedroom_count','bathroom_count','parking_count' ]]\
                        .apply(lambda x: (x<0).sum())
negative_count
# Out:
# price              0
# location_number    0
# zip_code           0
# bedroom_count      0
# bathroom_count     0
# parking_count      0
# dtype: int64

# %% [markdown]
# - Step   : Cehck if there are any Negetive values in the specified numeric columns. As -ve values i nthe dataset might not be logical sense. By removing -ve values , tt helps to identify potential error or inconsistences in the data.
#
# - Result : There is not -ve values in the dataset.

# %%
cleaned_df = df_6
cleaned_df
#output_path = r"clean_data.xlsx"
#cleaned_df.to_excel(output_path, index=False)
# Out:
#     property_type                                   listing_agency   price  \
# 0           House                      Professionals - DARWIN CITY  435000
# 1       Apartment  Nick Mousellis Real Estate - Eview Group Member  320000
# 2            Unit                Habitat Real Estate - THE GARDENS  310000
# 3           House                           Ray White - NIGHTCLIFF  259000
# 4            Unit              Carol Need Real Estate - Fannie Bay  439000
# ..            ...                                              ...     ...
# 739         House                Real Estate Central - DARWIN CITY  495000
# 740         House           Kassiou Constructions - HOWARD SPRINGS  601000
# 741         House           Kassiou Constructions - HOWARD SPRINGS  655000
# 742         House           Kassiou Constructions - HOWARD SPRINGS  675000
# 743          Unit                            Home Zone NT - DARWIN  399000
#
#      location_number         city  zip_code product_depth  bedroom_count  \
# 0          139468611  Darwin City       800      premiere            2.0
# 1          139463755  Darwin City       800      premiere            3.0
# 2          139462495  Darwin City       800      premiere            2.0
# 3          139451679  Darwin City       800      premiere            1.0
# 4          139433803  Darwin City       800      premiere            3.0
# ..               ...          ...       ...           ...            ...
# 739        138350855    Woodroffe       830       feature            4.0
# 740        138333062   Humpty Doo       836      standard            4.0
# 741        138333058   Humpty Doo       836      standard            4.0
# 742        138333050    Lee Point       810      standard            4.0
# 743        138330946  Stuart Park       820       feature            2.0
#
#      bathroom_count  parking_count
# 0               1.0            1.0
# 1               2.0            2.0
# 2               1.0            1.0
# 3               1.0            0.0
# 4               2.0            2.0
# ..              ...            ...
# 739             2.0            2.0
# 740             2.0            2.0
# 741             2.0            2.0
# 742             2.0            3.0
# 743             2.0            2.0
#
# [744 rows x 10 columns]

# %% [markdown]
# The dataset is cleaned and ready for analysis and exploration.
#
# *Step 3: Feature Understanding
# - Plotting feature distribution
# - Histogram, KDE, Boxplot

# %%
round(cleaned_df.describe(),2)
# Out:
#              price  location_number  zip_code  bedroom_count  bathroom_count  \
# count       744.00     7.440000e+02    744.00         744.00          744.00
# mean     574842.46     1.414840e+08    816.29           2.77            1.70
# std     1431358.55     4.138846e+07     13.63           1.09            0.61
# min           1.00     1.085305e+08    800.00           0.00            1.00
# 25%      380000.00     1.386080e+08    800.00           2.00            1.00
# 50%      489000.00     1.389919e+08    812.00           3.00            2.00
# 75%      610000.00     1.392743e+08    830.00           3.00            2.00
# max    38900000.00     7.001996e+08    839.00           8.00            5.00
#
#        parking_count
# count         744.00
# mean            2.09
# std             1.51
# min             0.00
# 25%             1.00
# 50%             2.00
# 75%             2.00
# max            12.00

# %%
#For learning.. To drop one perticular record
#i = cleaned_df[cleaned_df['price']==1].index
#cleaned_df_1 = cleaned_df.drop(i)

# %%
filtered_df =cleaned_df[cleaned_df['price'] >10000]
round(filtered_df.describe(),2)
# Out:
#              price  location_number  zip_code  bedroom_count  bathroom_count  \
# count       736.00     7.360000e+02    736.00         736.00          736.00
# mean     581085.26     1.415119e+08    816.22           2.76            1.69
# std     1437865.65     4.161221e+07     13.67           1.09            0.60
# min       99950.00     1.085305e+08    800.00           0.00            1.00
# 25%      383750.00     1.386080e+08    800.00           2.00            1.00
# 50%      490000.00     1.389919e+08    812.00           3.00            2.00
# 75%      612725.00     1.392750e+08    830.00           3.00            2.00
# max    38900000.00     7.001996e+08    839.00           8.00            5.00
#
#        parking_count
# count         736.00
# mean            2.07
# std             1.47
# min             0.00
# 25%             1.00
# 50%             2.00
# 75%             2.00
# max            12.00

# %% [markdown]
# *1. Price Statistics:
# -Price Range: The minimum price is AUD 99,950  , maximum price is 38900000.00

# %% [markdown]
# ##Property Dsstribution
# -Which property type has the highest demand in the market.
#
# Hypothesis Test Question:
# null Hypothesis        : Apartments are more expensive than the unit.
# Alternative hypothesis : Apartments are not expensive than the unit.

# %%
plt.figure(figsize=(30,10),dpi=150)

ax = sns.countplot(x='property_type' , data=cleaned_df)

plt.title('Property Distribution Count' ,fontsize = 30)
plt.xlabel('Property Type' , fontsize = 30)
plt.xticks(rotation=90, fontsize = 25)

plt.ylabel('Count' , fontsize=30)
plt.yticks(fontsize = 20)

plt.grid()
plt.show()
print(stats.normaltest(cleaned_df['price'].sample(50)))
# Out:
# NormaltestResult(statistic=99.27495967915547, pvalue=2.771509745757274e-22)

# %% [markdown]
# *Observation
# -House is the most common property type , with a count exceeding 300.
# -Apartment and Units have the similar counts ,sligtly below 200.
# -Townhouse has the notable count but significuntly less than house,apartment and unit.
# -other property types Studio, Acreage, Duplex/Semi-detached, Other, Villa has a very low count with villa being the least common.
# -House dominate the market, indicating a higher availability of prefrences for this property types.
#
# The p-value of 0.003 is much lower than the common alpha level of 0.05. This means we reject the null hypothesis that the Apartment are more expensive than the Unit.

# %% [markdown]
# #Price Distribution
# Hypothesis questiion : How is the property price distribution looks like?
# null hypothesis        : property prices are normally distributed.
# alternative hypothesis : property prices are not normally distributed.

# %%
#Price Distribution - Plot Histogram to see the price distribution 
sns.histplot(cleaned_df['price'],kde=True)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#Highest and Lowest Valued Property by City
highest_valued_city = cleaned_df.loc[cleaned_df['price'].idxmax()]['city']
print(f"The city with the highest valued property is:{highest_valued_city}")

lowest_valued_city = cleaned_df.loc[cleaned_df['price'].idxmin()]['city']
print(f"The city with the lowest valued property is:{lowest_valued_city}")
# Out:
# The city with the highest valued property is:Darwin City
# The city with the lowest valued property is:Johnston

# %%
plt.hist(cleaned_df['price'], bins=10)
plt.title("Distribution of Property Prices")
plt.xlabel('Proprty Price')
plt.ylabel('Counts')
plt.show()
print(stats.normaltest(cleaned_df['price'].sample(50)))
# Out:
# NormaltestResult(statistic=36.281563660116504, pvalue=1.3229960690570324e-08)

# %% [markdown]
# *Obesrvation
# The Histogram of the property prices is highly skewed to the left, indicating that the most properties are priced on the lower end, with the few property having very high prices. This skewness suggests a disparity in property prices.
#
# Result of the Normality test,
# The very low p-value (6.12 e-06) indicates that we reject the null hypothesis. This confirms that the property prices do not follow a normal distribution and are significantly skewed.
#
# Outlier Analysis: Identifying and analyzing the outliers separately can provide insights into the factors contributing to the extremely high property values.

# %%
#scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(cleaned_df['bedroom_count'], cleaned_df['price'], alpha=0.5)
plt.title('Scatter Plot of Price vs Bedroom Count')
plt.xlabel('Bedroom Count')
plt.ylabel('Price')
plt.show()

# %%
# Finding Outliers using IQR
Q1 = cleaned_df['price'].quantile(0.25)
Q3 = cleaned_df['price'].quantile(0.75)
IQR = Q3 - Q1
outliers = cleaned_df[(cleaned_df['price'] < (Q1 - 1.5 * IQR)) | (cleaned_df['price'] > (Q3 + 1.5 * IQR))]

# Define the lower bound and upper bound for non-outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 42

# %%
#Filter the Data to remove the outliers
df_no_outliers = cleaned_df[(cleaned_df['price'] >=lower_bound) & (cleaned_df['price'] <=upper_bound ) ]
#output_path = r"clean_data.xlsx"
#df_no_outliers.to_excel(output_path, index=False)
#output_path = r"clean_data.csv"
#df_no_outliers.to_csv(output_path, index=False)

# Display the number of records before and after removing outliers
print(f"Original data count: {len(cleaned_df)}")
print(f"Data count after removing outliers: {len(df_no_outliers)}")
# Out:
# Original data count: 744
# Data count after removing outliers: 702

# %% [markdown]
# *Removing Outliers
# After removing outliers, the dataset becomes more representative of the typical property price.

# %%
# Convert price to numeric, removing '$' and ',' if present
df_no_outliers['price'] = df_no_outliers['price'].replace('[\$,]', '', regex=True).astype(float)

# Agency representation analysis
agency_counts = df_no_outliers['listing_agency'].value_counts()
top_agencies = agency_counts.head(10)

print("Top 10 agencies by number of listings:")
print(top_agencies)

# Calculate market share
total_listings = len(df_no_outliers)
market_share = (agency_counts / total_listings * 100).round(2)

print("\nMarket share of top 10 agencies:")
print(market_share.head(10))
# Out:
# Top 10 agencies by number of listings:
# listing_agency
# Real Estate Central - DARWIN CITY                                                                       52
# Call2View Real Estate - Palmerston                                                                      34
# Elders Real Estate - Palmerston                                                                         33
# First National Real Estate O'Donoghues - Darwin                                                         32
# Knight Frank (NT) - Darwin                                                                              30
# Raine & Horne - Darwin                                                                                  26
# Elders Real Estate - Darwin                                                                             26
# For Sale By Owner                                                                                       23
# Renee's Realty NT - DURACK                                                                              23
# LJ Hooker Darwin -                                                                                      23
# Name: count, dtype: int64
#
# Market share of top 10 agencies:
# listing_agency
# Real Estate Central - DARWIN CITY                                                                       7.41
# Call2View Real Estate - Palmerston                                                                      4.84
# Elders Real Estate - Palmerston                                                                         4.70
# First National Real Estate O'Donoghues - Darwin                                                         4.56
# Knight Frank (NT) - Darwin                                                                              4.27
# Raine & Horne - Darwin                                                                                  3.70
# Elders Real Estate - Darwin                                                                             3.70
# For Sale By Owner                                                                                       3.28
# Renee's Realty NT - DURACK                                                                              3.28
# LJ Hooker Darwin -                                                                                      3.28
# Name: count, dtype: float64

# %%
# Property type focus
print("\nProperty type focus for top 5 agencies:")
for agency in top_agencies.head().index:
    print(f"\n{agency}:")
    print(df_no_outliers[df_no_outliers['listing_agency'] == agency]['property_type'].value_counts())
# Out:
# Property type focus for top 5 agencies:
#
# Real Estate Central - DARWIN CITY:
# property_type
# House                   22
# Apartment               14
# Unit                    12
# Townhouse                2
# Duplex/Semi-detached     2
# Name: count, dtype: int64
#
# Call2View Real Estate - Palmerston:
# property_type
# House                   28
# Apartment                2
# Unit                     2
# Townhouse                1
# Duplex/Semi-detached     1
# Name: count, dtype: int64
#
# Elders Real Estate - Palmerston:
# property_type
# House                   22
# Unit                     6
# Townhouse                3
# Duplex/Semi-detached     2
# Name: count, dtype: int64
#
# First National Real Estate O'Donoghues - Darwin:
# property_type
# Apartment               16
# House                    8
# Unit                     3
# Villa                    2
# Duplex/Semi-detached     2
# Townhouse                1
# Name: count, dtype: int64
#
# Knight Frank (NT) - Darwin:
# property_type
# Apartment    18
# House        11
# Townhouse     1
# Name: count, dtype: int64

# %%
# Price range analysis
price_analysis = df_no_outliers.groupby('listing_agency')['price'].agg(['mean', 'min', 'max']).round(0)
print("\nPrice analysis for top 10 agencies:")
print(price_analysis.loc[top_agencies.index])
# Out:
# Price analysis for top 10 agencies:
#                                                         mean       min  \
# listing_agency
# Real Estate Central - DARWIN CITY                   494135.0  165000.0
# Call2View Real Estate - Palmerston                  506559.0  244000.0
# Elders Real Estate - Palmerston                     535894.0  209000.0
# First National Real Estate O'Donoghues - Darwin     578250.0  260000.0
# Knight Frank (NT) - Darwin                          511033.0  190000.0
# Raine & Horne - Darwin                              477692.0  130000.0
# Elders Real Estate - Darwin                         478538.0  195000.0
# For Sale By Owner                              ...  514217.0  200000.0
# Renee's Realty NT - DURACK                          516870.0  200000.0
# LJ Hooker Darwin -                                  452565.0  149000.0
#
#                                                          max
# listing_agency
# Real Estate Central - DARWIN CITY                   795000.0
# Call2View Real Estate - Palmerston                  950000.0
# Elders Real Estate - Palmerston                     895000.0
# First National Real Estate O'Donoghues - Darwin     868000.0
# Knight Frank (NT) - Darwin                          895000.0
# Raine & Horne - Darwin                              775000.0
# Elders Real Estate - Darwin                         830000.0
# For Sale By Owner                              ...  800000.0
# Renee's Realty NT - DURACK                          899000.0
# LJ Hooker Darwin -                                  850000.0

# %%
# Geographic focus
print("\nTop 3 locations for top 5 agencies:")
for agency in top_agencies.head().index:
    print(f"\n{agency}:")
    print(df_no_outliers[df_no_outliers['listing_agency'] == agency]['city'].value_counts().head(3))
# Out:
# Top 3 locations for top 5 agencies:
#
# Real Estate Central - DARWIN CITY:
# city
# Darwin City    15
# Wagaman         3
# Driver          3
# Name: count, dtype: int64
#
# Call2View Real Estate - Palmerston:
# city
# Rosebery       7
# Darwin City    4
# Bakewell       4
# Name: count, dtype: int64
#
# Elders Real Estate - Palmerston:
# city
# Bakewell    6
# Gunn        6
# Durack      3
# Name: count, dtype: int64
#
# First National Real Estate O'Donoghues - Darwin:
# city
# Darwin City    15
# Millner         2
# Rosebery        2
# Name: count, dtype: int64
#
# Knight Frank (NT) - Darwin:
# city
# Darwin City    19
# Rosebery        3
# Driver          1
# Name: count, dtype: int64

# %%
# Visualizations
plt.figure(figsize=(12, 6))
top_agencies.plot(kind='bar')
plt.title('Top 10 Agencies by Number of Listings')
plt.xlabel('Agency')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("Fig1.png")
plt.show()

# %%
plt.figure(figsize=(12, 6))
df_no_outliers.groupby('listing_agency')['price'].mean().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Average Listing Price by Top 10 Agencies')
plt.xlabel('Agency')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig("Fig2.png")
plt.show()
